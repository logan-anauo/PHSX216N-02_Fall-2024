# %% [markdown]
# <a href="https://colab.research.google.com/github/logan-anauo/PHSX216N-02_Fall-2024/blob/main/Logan_Anauo_Lab_3_Projectile_Motion_PHSX216N_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PHSX 216 Projectile Motion Lab plotting code
#performs 2nd degree polynomial fit
#Brianna Beller
#Updated September 2024

import numpy as np
import matplotlib.pyplot as plt

#-----------------------------------------------------------------------#
#----------UPDATE THIS SECTION!!!----------

#DATA TO BE PLOTTED
#UPDATE THE VARIABLE NAMES & NUMBERS (LEAVE BRACKETS/PARENTHESES AS IS)
#variable names should start with a letter and must contain only letters, numbers, and underscores

theta_angle_degrees = np.array([44.0, 47.0, 41.0, 50.0, 38.0]) #what are units? degrees of angle theta   <-----

average_yhit_meters = np.array([0.9028, 0.8754, 0.9398, 0.7708, 0.8746]) #what are units? meters_from floor to hit mark  <-----

delta_average_yhit_meters = np.array([0.0161, 0.0111, 0.0051, 0.0091, 0.0061])  #uncertainty in average y_from standard deviation in excel  <-----

#Re-assign variables as x, y, dy so that the remaining plotting code may remain generic
#UPDATE VARIABLE NAMES (ON RHS OF EACH EQUAL SIGN) TO MATCH VARIABLE NAMES FOR DATA ABOVE

x = theta_angle_degrees             #this should be the array you want to plot on the x axis #        <-----
y = average_yhit_meters             #this should be the array you want to plot on the y axis #        <-----
dy = delta_average_yhit_meters        #this should be your error in y array                    #        <-----

#UPDATE EACH OF THESE 3 STRINGS FOR YOUR PLOT LABELS AS YOU WANT THEM TO APPEAR

plot_title= 'Projectile Motion - Experimental Optimum Angle of Launch'  #                 <-----
x_label= 'Projectile Launch Angle [degrees]'   #                 <-----
y_label= 'Height of Contact on Wall [meters]'   #                 <-----

#-----------------------------------------------------------------------#
#-----DON'T NEED TO CHANGE ANYTHING BEYOND THIS POINT!!!-----


#size the plot
plt.figure(figsize=(15,10))

#create scatter plot
plt.scatter(x, y, color='blue', marker='o')

#create labels
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)

#fitting to a 2nd degree polynomial
c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)

#Annotate with values of A, B, C from best fit polynomial
plt.annotate('best fit line: $f(x)=Ax^2+Bx+C$',(0.05, 0.95), xycoords='axes fraction')

plt.annotate('     A = {:.6f}'.format(a),(0.05, 0.9), xycoords='axes fraction')

plt.annotate('     B = {:.6f}'.format(b),(0.05, 0.85), xycoords='axes fraction')

plt.annotate('     C = {:.6f}'.format(c),(0.05, 0.8), xycoords='axes fraction')

#Create fit line
xnew = np.linspace(x.min(), x.max(), 300)
fit = a*xnew**2 + b*xnew +c

plt.plot(xnew, fit, color='green')
plt.show()
